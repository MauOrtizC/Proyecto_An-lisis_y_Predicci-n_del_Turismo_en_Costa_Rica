# %% [markdown]
# ## Carga inicial

# %% [markdown]
# ### Utilizar la clase GestorDatos

# %% [markdown]
# ### Archivos de diferentes fechas que comparten estructura, para combinarlos

# %%
from src.datos.Gestor_Datos import GestorDatos
gestor = GestorDatos(ruta_base="../data")

df = gestor.combinar_datos_por_anio("2c.txt", "Cuadro_1_llegadas_todas_las_vias_2026.txt")
# Out:
# TXT convertido a CSV → ../data\processed\2c.csv
# Archivo cargado: 2c.txt (83 filas, 14 columnas)
# Datos limpiados: valores nulos reemplazados por 0.
# TXT convertido a CSV → ../data\processed\Cuadro_1_llegadas_todas_las_vias_2026.csv
# Archivo cargado: Cuadro_1_llegadas_todas_las_vias_2026.txt (83 filas, 4 columnas)
# Datos limpiados: valores nulos reemplazados por 0.
# Archivos combinados correctamente con nombres restaurados y totales calculados.

# %% [markdown]
# ### Exportar datos que se combinaron a Processed

# %%
gestor.exportar_datos(df, "turismo_combinado_2025_2026_fechas.csv")
# Out:
# Archivo exportado correctamente en: ../data\processed\turismo_combinado_2025_2026_fechas.csv

# %% [markdown]
# ### Para archivos individuales

# %%
from src.datos.Gestor_Datos import GestorDatos
gestor = GestorDatos(ruta_base="../data")

# %% [markdown]
# ### Exportar datos a Processed

# %%
df_hist = gestor.procesar_archivo_individual("TurismoHistorico.csv")
