# %% [markdown]
# ## Carga inicial

# %% [markdown]
# ### Utilizar la clase GestorDatos

# %% [markdown]
# ### Archivos de diferentes fechas que comparten estructura, para combinarlos

# %%
from src.datos.Gestor_Datos import GestorDatos
# Crear instancia del gestor de datos
gestor = GestorDatos(ruta_base="../data")

# Verificar rutas disponibles
print("Carpeta RAW:", gestor.ruta_raw)
print("Carpeta PROCESSED:", gestor.ruta_processed)

# Combinar archivos del 2025 y 2026
df_combinado = gestor.combinar_datos_por_anio("[2025_por_Meses].csv", "[2025_por_Meses].csv")

# Mostrar las primeras filas del resultado
df_combinado.head()
# Out:
# Carpeta RAW: ../data\raw
# Carpeta PROCESSED: ../data\processed
# Archivo cargado: [2025_por_Meses].csv (83 filas, 15 columnas)
# Datos limpiados: valores nulos o vacíos reemplazados por 0.
# Archivo cargado: [2025_por_Meses].csv (83 filas, 15 columnas)
# Datos limpiados: valores nulos o vacíos reemplazados por 0.
# Archivos 2025 y 2026 combinados correctamente.
#             Zona_Pais   01-2025   02-2025   03-2025   04-2025   05-2025  \
# 79              TOTAL  298475.0  293784.0  336476.0  252867.0  205803.0
# 3   AMERICA DEL NORTE  202581.0  199882.0  247595.0  171151.0  149633.0
# 16             CANADA   42440.0   39843.0   38851.0   23193.0   11508.0
# 29     ESTADOS UNIDOS  154170.0  153380.0  200831.0  138949.0  130004.0
# 49             MEXICO    5971.0    6659.0    7913.0    9009.0    8121.0
#
#      06-2025   07-2025   08-2025   09-2025   10-2025   11-2025   12-2025  \
# 79  232571.0  262048.0  199959.0  121815.0  145663.0  247387.0  347143.0
# 3   177467.0  179300.0  124758.0   69698.0   85817.0  157377.0  234341.0
# 16    8996.0   12551.0   10399.0    5144.0    9703.0   28897.0   42556.0
# 29  161583.0  156348.0  104920.0   57064.0   69581.0  119833.0  181144.0
# 49    6888.0   10401.0    9439.0    7490.0    6533.0    8647.0   10641.0
#
#      01-2026   02-2026  Total_2025  Total_2026      Total
# 79  298475.0  293784.0   2943991.0   2943991.0  5887982.0
# 3   202581.0  199882.0   1999600.0   1999600.0  3999200.0
# 16   42440.0   39843.0    274081.0    274081.0   548162.0
# 29  154170.0  153380.0   1627807.0   1627807.0  3255614.0
# 49    5971.0    6659.0     97712.0     97712.0   195424.0

# %% [markdown]
# ### Exportar datos que se combinaron a Processed

# %%
# Exportar el DataFrame combinado
gestor.exportar_datos(df_combinado, "turismo_combinado_2025_2026.csv")
# Out:
# Archivo exportado correctamente en: ../data\processed\turismo_combinado_2025_2026.csv

# %% [markdown]
# ### Para archivos individuales

# %%
# Procesar archivo individual
df_hist = gestor.procesar_archivo_individual("Turismo_Historico.csv")

# Ver primeras filas
df_hist.head()
# Out:
# Archivo cargado: Turismo_Historico.csv (100 filas, 11 columnas)
# Datos limpiados: valores nulos o vacíos reemplazados por 0.
# 📤 Columna 'id' eliminada.
# 📦 Fila 'Total' movida al final.
# Archivo exportado correctamente en: ../data\processed\Turismo_Historico_procesado.csv
# ✅ Archivo procesado y exportado como: Turismo_Historico_procesado.csv
# Filas: 100, Columnas: 10
# Columnas finales: ['Zona_Pais', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025']
#            Zona_Pais       2017       2018       2019      2020      2021  \
# 1  AMERICA DEL NORTE  1507945.0  1580991.0  1666571.0  571010.0  958792.0
# 2             CANADA   201921.0   217006.0   234621.0  115632.0   53185.0
# 3     ESTADOS UNIDOS  1199241.0  1265067.0  1334777.0  434775.0  868986.0
# 4             MEXICO   106783.0    98918.0    97173.0   20603.0   36621.0
# 5    AMERICA CENTRAL   735178.0   691386.0   698601.0  202374.0   78425.0
#
#         2022       2023     2024       2025
# 1  1533502.0  1820038.0  1989725  1999600.0
# 2   183678.0   260744.0   272256   274081.0
# 3  1290038.0  1473620.0  1621340  1627807.0
# 4    59786.0    85674.0    96129    97712.0
# 5   194242.0   235712.0   235860   247850.0

# %%
gestor.exportar_datos(df_hist, "TurismoHistorico_procesado.csv")
# Out:
# Archivo exportado correctamente en: ../data\processed\TurismoHistorico_procesado.csv

# %%
from src.datos.gestor_datos import GestorDatos

gd = GestorDatos(ruta_base="../data")
df_proc = gd.procesar_archivo_individual("Turismo_Historico5.txt")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.datos.gestor_datos import GestorDatos
#       3 gd = GestorDatos(ruta_base="../data")
#       4 df_proc = gd.procesar_archivo_individual("Turismo_Historico5.txt")
#
# ModuleNotFoundError: No module named 'src.datos.gestor_datos'
