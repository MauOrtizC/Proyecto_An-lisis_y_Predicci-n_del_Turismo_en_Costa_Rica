# %% [markdown]
# ## Carga inicial

# %% [markdown]
# ### Importar la clase GestorDatos

# %%
from src.datos.Gestor_Datos import GestorDatos

# Crear instancia (ajusta la ruta base si el notebook está al mismo nivel del proyecto)
gestor = GestorDatos(ruta_base="../data")

# Combinar los archivos de 2025 y 2026
df_combinado = gestor.combinar_datos_por_anio("2c.txt", "Cuadro_1_llegadas_todas_las_vias_2026.txt")

# Mostrar las primeras filas
df_combinado.head()
# Out:
# TXT convertido a CSV → ../data\processed\2c.csv
# Archivo cargado: 2c.txt (83 filas, 14 columnas)
# Datos limpiados: valores nulos reemplazados por 0.
# TXT convertido a CSV → ../data\processed\Cuadro_1_llegadas_todas_las_vias_2026.csv
# Archivo cargado: Cuadro_1_llegadas_todas_las_vias_2026.txt (83 filas, 4 columnas)
# Datos limpiados: valores nulos reemplazados por 0.
# Archivos 2025 y 2026 combinados correctamente con formato de fecha (MM-YYYY).
#             Zona_Pais   01-2025   02-2025   03-2025   04-2025   05-2025  \
# 96              TOTAL  298475.0  293784.0  336476.0  252867.0  205803.0
# 3   AMERICA_DEL_NORTE  202581.0  199882.0  247595.0  171151.0  149633.0
# 19             CANADA   42440.0   39843.0   38851.0   23193.0   11508.0
# 33     ESTADOS_UNIDOS  154170.0  153380.0  200831.0  138949.0  130004.0
# 55             MEXICO    5971.0    6659.0    7913.0    9009.0    8121.0
#
#      06-2025   07-2025   08-2025   09-2025   10-2025   11-2025   12-2025  \
# ...

# %% [markdown]
# ## Exportar datos cargados y procesados a Processed

# %%
# Exportar el resultado procesado en UTF‑8‑SIG (para mostrar tildes correctamente)
gestor.exportar_datos(df_combinado, "turismo_combinado_2025_2026_fechas.csv")
# Out:
# Archivo exportado correctamente en: ../data\processed\turismo_combinado_2025_2026_fechas.csv (UTF-8 con tildes soportadas)
