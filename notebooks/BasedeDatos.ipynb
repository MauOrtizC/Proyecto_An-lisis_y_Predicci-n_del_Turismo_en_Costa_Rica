# %% [markdown]
# ### Instalación de librerías necesarias

# %%
import pyodbc
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importar la clase

# %%
from src.basedatos.BaseDatos import BaseDatos

# %% [markdown]
# ## Crear instancia y conectar

# %%
db = BaseDatos(
    server="proyectofinalprogra.public.f9cbfb82504a.database.windows.net,3342",
    database="Turismo_CR",
    username="adminprogra",
    password="Tortuguita1000$$")

# Conectar
db.conectar()
# Out:
# ✅ Conexión exitosa a la base de datos.

# %%
query = "SELECT TOP 100 * FROM [2025_por_Meses];"
df = db.ejecutar_consulta(query)
df.head()
# Out:
# C:\Proyecto_Análisis_y_Predicción_del_Turismo_en_Costa_Rica\src\basedatos\BaseDatos.py:37: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, self.conn)
#    id          Zona_Pais     Enero   Febrero     Marzo     Abril      Mayo  \
# 0   1              TOTAL  298475.0  293784.0  336476.0  252867.0  205803.0
# 1   2  AMERICA DEL NORTE  202581.0  199882.0  247595.0  171151.0  149633.0
# 2   3             CANADA   42440.0   39843.0   38851.0   23193.0   11508.0
# 3   4     ESTADOS UNIDOS  154170.0  153380.0  200831.0  138949.0  130004.0
# 4   5             MEXICO    5971.0    6659.0    7913.0    9009.0    8121.0
#
#       Junio     Julio    Agosto  Setiembre   Octubre  Noviembre  Diciembre  \
# 0  232571.0  262048.0  199959.0   121815.0  145663.0   247387.0   347143.0
# ...

# %%
db.exportar_csv(df, "Turismo_Historico")
# Out:
# ✅ Archivo CSV exportado correctamente en: C:\Proyecto_Análisis_y_Predicción_del_Turismo_en_Costa_Rica\data\raw\Turismo_Historico.csv

# %%
db.exportar_csv(df, "[2025_por_Meses]")
# Out:
# ✅ Archivo CSV exportado correctamente en: C:\Proyecto_Análisis_y_Predicción_del_Turismo_en_Costa_Rica\data\raw\[2025_por_Meses].csv

# %%
db.exportar_csv(df, "[2026_por_Meses]")
# Out:
# ✅ Archivo CSV exportado correctamente en: C:\Proyecto_Análisis_y_Predicción_del_Turismo_en_Costa_Rica\data\raw\[2026_por_Meses].csv
